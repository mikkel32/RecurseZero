# %% [markdown]
# # 🧠 RecurseZero: GPU-Resident Chess AI
#
# **Easiest Method:** Mount Google Drive and sync your project folder there.
#
# > Go to `Runtime > Change runtime type > GPU` before running.

# %%
#@title 🚀 Setup + Mount Drive
import os

# Verify GPU
# !nvidia-smi -L

# Install dependencies
# !pip install -q jax[cuda12] flax optax pgx

# Verify JAX GPU
import jax
print(f"\n✅ JAX Backend: {jax.default_backend()}")
print(f"✅ Devices: {jax.devices()}")

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Set path to your RecurseZero folder in Drive
# Change this path if you put it somewhere else
PROJECT_PATH = '/content/drive/MyDrive/RecurseZero'

if os.path.exists(PROJECT_PATH):
    os.chdir(PROJECT_PATH)
    print(f"\n📂 Working directory: {os.getcwd()}")
    print(f"📁 Files: {os.listdir('.')}")
else:
    print(f"\n⚠️ Folder not found at: {PROJECT_PATH}")
    print("   Upload your RecurseZero folder to Google Drive first.")
# Out:
# GPU 0: Tesla T4 (UUID: GPU-e39515b6-c597-f8a7-2204-77cfb2d46c70)
#
# ✅ JAX Backend: gpu
# ✅ Devices: [CudaDevice(id=0)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-218847486.py in <cell line: 0>()
#      15 # Mount Google Drive
#      16 from google.colab import drive
# ---> 17 drive.mount('/content/drive')
#      18
#      19 # Set path to your RecurseZero folder in Drive
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# ...

# %%
#@title 🎮 Run Training
# !python main.py

# %%
#@title 📊 GPU Monitor
# !nvidia-smi dmon -s u -d 5 -c 10
