# %% [markdown]
# # 🧠 RecurseZero: GPU-Resident Chess AI
#
# **Easiest Method:** Mount Google Drive and sync your project folder there.
#
# > Go to `Runtime > Change runtime type > GPU` before running.

# %%
#@title 🚀 Setup (No Drive Required)
import os

# Verify GPU
# !nvidia-smi -L

# Clone RecurseZero directly
if not os.path.exists('/content/RecurseZero'):
    # !git clone https://github.com/mikkel32/RecurseZero.git
    
os.chdir('/content/RecurseZero')

# Install dependencies
# !pip install -q jax[cuda12] flax optax pgx rich

# Verify JAX
import jax
print(f"\n✅ JAX Backend: {jax.default_backend()}")
print(f"✅ Devices: {jax.devices()}")
print(f"📂 Working directory: {os.getcwd()}")
# Out:
# GPU 0: Tesla T4 (UUID: GPU-e39515b6-c597-f8a7-2204-77cfb2d46c70)
#
# ✅ JAX Backend: gpu
# ✅ Devices: [CudaDevice(id=0)]
# 📂 Working directory: /content/RecurseZero

# %%
#@title 🎮 Run Training
# !python main.py
# Out:
# Initializing RecurseZero...
# RecurseZero Hardware Setup: Backend=gpu, X64=False
# Applying Pygmalion Metal Patch to Pgx Chess...
# Patch applied successfully.
# Environment initialized with Batch Size: 2048, Actions: 4672
# Model and Optimizer initialized.
# Starting Resident Training Loop for 50 steps...
# Step 0: Loss=-5.1556, Reward=-1.0000
# Traceback (most recent call last):
#   File "/content/RecurseZero/main.py", line 82, in <module>
#     main()
#   File "/content/RecurseZero/main.py", line 63, in main
#     train_state, env_state, metrics = step_fn(
#                                       ^^^^^^^^
#   File "<string>", line 1, in <lambda>
# KeyboardInterrupt
# ^C

# %%
#@title 📊 GPU Monitor
# !nvidia-smi dmon -s u -d 5 -c 10
